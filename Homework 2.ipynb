# %% [markdown]
# Pre-lecture

# %%
#question 1 : 

#here is my understading of the code: 


import numpy as np
all_door_options = (1,2,3)  # tuple representing doors
my_door_choice = 1  # the initial choice of door
i_won = 0  # counter for wins
reps = 100000  # number of simulations
for i in range(reps): #This loop runs reps times (100,000 iterations) to simulate the game multiple times.
    secret_winning_door = np.random.choice(all_door_options)# Randomly selects one of the doors (1, 2, or 3) as the winning door.
    all_door_options_list = list(all_door_options)
    all_door_options_list.remove(secret_winning_door)
    try:
        all_door_options_list.remove(my_door_choice)
    except:
        pass
    #Converts the tuple of doors to a list and removes the winning door. If the initial choice of the door was the winning door, it will be removed as well.
    goat_door_reveal = np.random.choice(all_door_options_list)
    all_door_options_list.remove(goat_door_reveal)
    #Randomly selects and removes one of the losing doors (a door that is not the winning door and not the initial choice).
    if secret_winning_door != my_door_choice:
        all_door_options_list.append(secret_winning_door)
    my_door_choice = all_door_options_list[0]
    #If the winning door was not the initial choice, it is added back to the list of remaining doors. This is because the winning door was temporarily removed and needs to be reinstated if it wasn't the initial choice.
    #The code simulates switching to the only remaining door, which is now the only choice left after a losing door is revealed.
    if my_door_choice == secret_winning_door:
        i_won += 1
    #If the final door choice matches the winning door, increment the win counter.
        
i_won/reps
#After completing all simulations, this line calculates the fraction of times the final choice was the winning door, which approximates the probability of winning when always switching doors.
# Out:
# 0.6669

# %%
# question 2 
# here is the code that chatgpt gives me when I ask it to give me a simple version of the code. 

import numpy as np

# Constants
all_door_options = [1, 2, 3]  # List of doors
my_initial_choice = 1  # Initial choice
num_simulations = 100000  # Number of simulations

# Counter for wins
wins = 0

# Simulation loop
for _ in range(num_simulations):
    # Randomly select the winning door
    winning_door = np.random.choice(all_door_options)
    
    # Select a door to reveal (which is not the winning door and not the initial choice)
    doors_to_reveal = [door for door in all_door_options if door != winning_door and door != my_initial_choice]
    revealed_door = np.random.choice(doors_to_reveal)
    
    # The remaining door after revealing one
    remaining_doors = [door for door in all_door_options if door != revealed_door and door != my_initial_choice]
    
    # Simulate switching to the remaining door
    final_choice = remaining_doors[0]
    
    # Check if the final choice is the winning door
    if final_choice == winning_door:
        wins += 1

# Calculate the probability of winning by switching
probability_of_winning = wins / num_simulations
print(f"Probability of winning by switching: {probability_of_winning:.4f}")
# Out:
# Probability of winning by switching: 0.6688

# %% [markdown]
# My comparsion between the orginal code and the new code:
#
# The original code was started with tuple and then switched to list later on when it needs to drop the winning door. The new code that Chatgpt gives me start directly with creating list of door 1, door 2, and door 3 and it is more simple since no need to switch later on in other lines of code. The new line code directly creates filtered lists of remaining door using lists comprehensions, avoiding the repeats conversions and removels. In terms of efficiency and how easy to understand the code, the oiriginal code is more complex, since it has multiple manipulations, removals and conditional statements. The new code provides me with a clarity by using list comprehensions and avoid manipulations. It reduces more steps and making more easier to follow. Since, I prefer the new code that Chatgpt provided to me.

# %%
# question 3 
# here is the explain of the new code


import numpy as np

# Constants
all_door_options = [1, 2, 3]  # List of doors
my_initial_choice = 1  # Initial choice
num_simulations = 100000  # Number of simulations

# Counter for wins
wins = 0

# Simulation loop
for _ in range(num_simulations):
    # Randomly select the winning door from all choices:
    winning_door = np.random.choice(all_door_options)
    
    # Select a door to reveal (which is not the winning door and not the initial choice):
    doors_to_reveal = [door for door in all_door_options if door != winning_door and door != my_initial_choice]
    revealed_door = np.random.choice(doors_to_reveal)
    
    # The remaining door after revealing one:
    remaining_doors = [door for door in all_door_options if door != revealed_door and door != my_initial_choice]
    
    # Simulate switching to the remaining door:
    final_choice = remaining_doors[0]
    
    # Check if the final choice is the winning door:
    if final_choice == winning_door:
        wins += 1
    # this is a if statement saying that is the final choice is the winning door that the player wins. 
# Calculate the probability of winning by switching:
probability_of_winning = wins / num_simulations
print(f"Probability of winning by switching: {probability_of_winning:.4f}")


Overall Explanation:
    
This code processes a list of words, keeping track of:

How many times each word appears (word_used).
What words follow each word and how frequently they do (next_word).

# %%
# question 4 

# Markov Chains and Text Generation
from IPython.display import YouTubeVideo
YouTubeVideo('56mGTszb_iM', width = 550)


#Base on the chatbot I learned the information that the fisrt line initializes an empty dictionary named word_used and the second line initializes an empty dictionary named next_word.
# next, it follows with a loop  The loop goes through each word in the list words (except for the last one because we're always looking one word ahead).
# then, the if then statement crfeates the conditonal statement of if the words is used, increase the count by 1, if the word is not used Adds the word to the word_used dictionary with an initial count. otherwise, 
# the nex
# Markovian Chatbot

# from collections import defaultdict
word_used = dict() # defaultdict(int)


next_word = dict() # defaultdict(lambda: defaultdict(int))
for i,word in enumerate(words[:-1]):

    if word in word_used:
        word_used[word] += 1
    else:
        word_used[word] = 1
        next_word[word] = {}

    if words[i+1] in next_word[word]:
        next_word[word][words[i+1]] += 1
        # here Checks if the next word (words[i+1]) already exists in the dictionary of follow-up words for the current word (next_word[word]).
    else:
        next_word[word][words[i+1]] = 1

# %% [markdown]
# question 5
#
# The ChatBot quickly adapted to the concept of character-specific Markov chains. Within moments, it explained that this extension allows for the creation of unique models for different characters, enabling the generation of text that captures their individual styles.

# %% [markdown]
# question 6
#
# 1)
# The ChatBot provided quick and helpful responses to most of the questions for the homework. It offered a concise explanation that was easy to understand, demonstrating its ability to provide relevant information efficiently. If don't understand the code, it can explain to with very easily and it saves a lot of time.
#
# 2)
# While helpful, chatbots may not always understand the context of your specific issue, leading to generic answers. It's also important to verify any information or code provided.I do agree sometimes it can be very frustrating since there will be time where AI do not understand what you are asking for. Most of the time, I need to think if the question I ask can answer vy a robot. AI is just pretty popular this couple year so it is still not very matured.  Also, the free version of chatgpt has many limitations, sometimes you want to ask question about a certain image, but you are not able to upload one.
#
#
# 3)
# It is useful in a certain since it will give you the options of what stuff you need to check over.For example, spelling, syntax. Chatbots can offer relevant code snippets or examples, helping me to see how certain functions or libraries are used in practice. However, sometimes it give a too general idea that it is not detailed enough for me to actually know how to fix a error in a piece of code right away. I often need to look over and over to understand what chatgpt is saying because soemtimes the language the it provide was very robot.

# %% [markdown]
# question 7
#
#
# Since joining this course, my perception of AI-driven assistance tools like ChatBot has evolved significantly. Initially, I viewed these tools primarily as convenient aids for quick answers or debugging assistance. However, over time, I've come to realize their broader potential in enhancing my learning process, especially in complex fields like coding, statistics, and data science. By using AI as a resources for my studying, I can understand deeper and clear of the coding that was provided in this course. My confidence in applying coding and data science concepts has grown, as I can experiment with AI-generated code, ask follow-up questions, and immediately implement solutions. Even something I do not understand the solution that the chat bot provided to me, I can still ask for more detailed clarification. It’s a pretty new learning experience to me, since it allows me to iteratively refine my approach rather than relying solely on static resources like textbooks that was given by the prof.

# %% [markdown]
# question 8
#
# 1)
#
# Chatgpt in the modern world, particularly in the data science industry there is couple skills that you need to master. Learning and adaptability, communication, coding, and statistics and data analysis. All of these skills is really important to career relevance. Employers value individuals who demonstrate a willingness and ability to learn, as it indicates potential for long-term growth. Strong communication skill help bridge the gap between techinical and business strategy and coding skills is non-negotiable for technical roles in data science career.
#
# 2)
#
# In this praticular conversations with chatgpt. Chatbot explains that being a statistician or data scientist without coding or doing data analysis can be very diffcult, since data scientist often deal with dataset that cannot be efficiently working manually.
#
#
# 3)
#
#
# The link are at the bottom of my notebook
#
#
#
# 4)
#
# Reflecting on my recent conversations about my potential career paths, I've gained a clearer understanding of my interests and the skills I need to develop. I realize that pursuing a career that aligns with my passions will require a focused effort on building specific competencies. I also recognize the importance of networking. Engaging with professionals in my areas of interest can provide valuable insights and guidance. Overall, I feel motivated to take actionable steps toward my career goals, knowing that continuous learning and adaptation is important to my success.
#
#
#
#
# 5)
#
# I definitely agree with that there is limitations of the coversation with chatgpt. Since I think that chatgpt is not someone that has real exprience in real world. The next step I can do persue this conversation is ask more speicifc part of the points that Chatgpt provided to me. I will tell Chatgpt that I really want to persue a in career and can you introduce this careerpath detaily.

# %% [markdown]
# Question 9
#
# Yes, I did check the weekly course weekly textbook, and interacted with chatbot which provided me with more clarification of the course content. I also know where I can find the office hours for TA on quercus.
# For the more challenging topics, I turned to the Piazza discussion board to see how other students approached similar questions.

# %% [markdown]
# here is my cahtgpt links:
# https://chatgpt.com/share/66e700f6-6580-8001-9a87-566510dbd4de
# https://chatgpt.com/share/66e89b9f-e640-8001-9ab2-1def3e3a7aa1
# https://chatgpt.com/c/66eb370d-ba34-8013-b400-8341d7b33c20
